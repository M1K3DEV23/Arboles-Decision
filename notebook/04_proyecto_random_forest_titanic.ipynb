# %% [markdown]
# # Arbol de decision con scikit-learn

# %% [markdown]
# ## Importamos las librerias principales

# %%
# Graficas
import matplotlib.pyplot as plt
# Manipulacion de datos
import numpy as np
import pandas as pd
import seaborn as sns

# Balanceo
from imblearn.combine import SMOTEENN
from imblearn.under_sampling import RandomUnderSampler

# Creacion del modelo de Random Forest
from sklearn.ensemble import RandomForestClassifier

# Metricas del modelo
from sklearn.metrics import ConfusionMatrixDisplay, accuracy_score, confusion_matrix

# Division de datos
from sklearn.model_selection import GridSearchCV, train_test_split

sns.set_theme(style="whitegrid", palette="muted", context='notebook')

# %% [markdown]
# Utilizaremos el [dataset Titanic de Standford](https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/problem12.html)
#
# ## Cargamos el dataset a utilizar

# %%
df = pd.read_csv('../data/titanic.csv', sep=',')

# %% [markdown]
# # Analisis Exploratorio de datos

# %% [markdown]
# ## Atributos del dataset
#
# El conjunto de datos Titanic de CS109 contiene 887 observacioes y 8 variables
#
# - Survived (Sobrevivió): indica si el pasajero sobrevivió al hundimiento del Titanic (0 = No, 1 = Sí).
#
# - Pclass (Clase de pasajero): indica la clase del pasajero (1 = 1ª clase, 2 = 2ª clase, 3 = 3ª clase).
#
# - Sex (Género): el género del pasajero (Masculino o Femenino).
#
# - Age (Edad): la edad del pasajero en años.
#
# - Siblings/Spouses Aboard (Hermanos/Cónyuges a bordo): el número de hermanos/cónyuges del pasajero que también estaban a bordo del Titanic.
#
# - Parents/Children Aboard (Padres/Hijos a bordo): el número de padres/hijos del pasajero que también estaban a bordo del Titanic.
#
# - Fare (Tarifa): la tarifa pagada por el pasajero por su viaje en el Titanic.

# %% [markdown]
# Visualizacion del DataFrame

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500

# %% [markdown]
# Eliminamos las columnas que no nos interesan `Name, Fare`
#
# Se eliminará la columna "Fare" ya que esta información está altamente correlacionada con la columna "Pclass" que nos indica la lase social del pasajero. Además, se eliminará la columna "Name" ya que no es relevante para el análisis que se realizará.

# %%
columns_to_drop = ['Name', 'Fare']

df.drop(columns_to_drop, axis='columns', inplace=True)

# %% [markdown]
# Renombramos las columnas

# %%
df.columns = ['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch']
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch
# 0         0       3    male  22.0      1      0
# 1         1       1  female  38.0      1      0
# 2         1       3  female  26.0      0      0
# 3         1       1  female  35.0      1      0
# 4         0       3    male  35.0      0      0

# %% [markdown]
# Analizamos las observaciones y variables

# %%
print(df.shape)
# Out:
# (887, 6)

# %% [markdown]
# Visualizamos los tipos de datos

# %%
df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# dtype: object

# %% [markdown]
# Cambiamos el tipo de dato de sex a binario

# %%
df = pd.get_dummies(df, columns=['Sex'], drop_first=True, dtype=int)

# %%
df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Age         float64
# SibSp         int64
# Parch         int64
# Sex_male      int64
# dtype: object

# %%
df.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch  Sex_male
# 0         0       3  22.0      1      0         1
# 1         1       1  38.0      1      0         0
# 2         1       3  26.0      0      0         0
# 3         1       1  35.0      1      0         0
# 4         0       3  35.0      0      0         1

# %% [markdown]
# Se modifico el nombre de `sex` a `Sex_male` tenemos que volver a ponerle el nombre original

# %%
df.rename(columns={'Sex_male': 'Sex'}, inplace=True)

# %% [markdown]
# - Sex = 1 = Male
#
# - Sex = 0 = Female

# %% [markdown]
# Ordenar las columnas por nombres

# %%
df = df[['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch']]
df.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch
# 0         0       3    1  22.0      1      0
# 1         1       1    0  38.0      1      0
# 2         1       3    0  26.0      0      0
# 3         1       1    0  35.0      1      0
# 4         0       3    1  35.0      0      0

# %% [markdown]
# # Entrenamiento de Random Forest con Scikit-learn

# %% [markdown]
# Separar mi variable target de todas aquellas que no forman el target

# %%
# Todas las variables excepto la target
X = df.drop('Survived', axis=1)

# Variable target a predecir
y = df['Survived']

# %% [markdown]
# Veamos la proporcion del la variable target

# %%
df['Survived'].value_counts(normalize=True) * 100
# Out:
# Survived
# 0    61.443067
# 1    38.556933
# Name: proportion, dtype: float64

# %% [markdown]
# Balanceamos los datos

# %%
sme = SMOTEENN(sampling_strategy=0.99, random_state=42)

X_res, y_res = sme.fit_resample(X, y)

# Como se encuentra destribuidos luego del balanceo

# %%
y_res.value_counts(normalize=True) * 100
# Out:
# Survived
# 1    54.166667
# 0    45.833333
# Name: proportion, dtype: float64

# %%
under_sample = RandomUnderSampler(random_state=42)

X_under, y_under = under_sample.fit_resample(X, y)

# %%
y_under.value_counts(normalize=True) * 100
# Out:
# Survived
# 0    50.0
# 1    50.0
# Name: proportion, dtype: float64

# %% [markdown]
# Dividir el dataset en porcentaje
#
# - **30% para TEST**
#
# - **70% para TRAIN**

# %%
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.30, random_state=42)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_under, y_under, test_size=0.30, random_state=42)

# %% [markdown]
# ## Creacion del modelo

# %% [markdown]
# Hiper parametros

# %%
param_grid = {
    "n_estimators": [5, 10, 25, 50],
    "max_depth": [5, 10, 15],
    "criterion": ["gini", "entropy", "log_loss"],
    "min_samples_split": [2, 4, 6],
    "min_samples_leaf": [1, 2, 4]
}

# %% [markdown]
# Definir el clasificador y los valores de los hiper parametros a probar

# %%
rfc_model = RandomForestClassifier(random_state=42)
# Realizar la busqueda de hiperparametros utilizando GridSearchCV
grid_search = GridSearchCV(rfc_model, param_grid=param_grid, cv=10, scoring='accuracy', return_train_score=True)

# %% [markdown]
# Entrenamiento del modelo

# %%
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10, estimator=RandomForestClassifier(random_state=42),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [5, 10, 15],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 4, 6],
#                          'n_estimators': [5, 10, 25, 50]},
#              return_train_score=True, scoring='accuracy')

# %% [markdown]
# Ver los puntajes de cada criterion y la profundidad

# %%
for params, mean_score in zip(grid_search.cv_results_['params'], grid_search.cv_results_['mean_test_score']):
    print(f"Parametros: {params}\n")
    print("="*70)
    print(f"Mean Score: {mean_score}")
# Out:
# Parametros: {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7845301418439716
# Parametros: {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7950354609929078
# Parametros: {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7992021276595744
# Parametros: {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7992021276595744
# Parametros: {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.788741134751773
# Parametros: {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7886968085106384
# Parametros: {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7971631205673759
# Parametros: {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7992464539007093
# Parametros: {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7803191489361703
# Parametros: {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7761524822695035
# Parametros: {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7888297872340425
# Parametros: {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.8034131205673759
# Parametros: {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7741578014184398
# Parametros: {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7720301418439717
# Parametros: {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7845744680851063
# Parametros: {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7929964539007092
# Parametros: {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7741578014184398
# Parametros: {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7720301418439717
# Parametros: {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7845744680851063
# Parametros: {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7929964539007092
# Parametros: {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.767863475177305
# Parametros: {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7678191489361702
# Parametros: {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7908244680851063
# Parametros: {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7992464539007091
# Parametros: {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.774113475177305
# Parametros: {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7887854609929078
# Parametros: {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7909574468085105
# Parametros: {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7867021276595745
# Parametros: {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.774113475177305
# Parametros: {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7887854609929078
# Parametros: {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7909574468085105
# Parametros: {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7867021276595745
# Parametros: {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.774113475177305
# Parametros: {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7887854609929078
# Parametros: {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7909574468085105
# Parametros: {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7867021276595745
# Parametros: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7719414893617021
# Parametros: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7699024822695035
# Parametros: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7781914893617021
# Parametros: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7803191489361702
# Parametros: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7824024822695035
# Parametros: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7908244680851064
# Parametros: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7845301418439716
# Parametros: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7782801418439717
# Parametros: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7614361702127659
# Parametros: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7824911347517729
# Parametros: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7908687943262411
# Parametros: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7845744680851064
# Parametros: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7593528368794327
# Parametros: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.782491134751773
# Parametros: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7867907801418441
# Parametros: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7825797872340426
# Parametros: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7593528368794327
# Parametros: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.782491134751773
# Parametros: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7867907801418441
# Parametros: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7825797872340426
# Parametros: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7720301418439716
# Parametros: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7824911347517731
# Parametros: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7847074468085107
# Parametros: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7867464539007093
# Parametros: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7827127659574468
# Parametros: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7867464539007092
# Parametros: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7846187943262412
# Parametros: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7826241134751774
# Parametros: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7827127659574468
# Parametros: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7867464539007092
# Parametros: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7846187943262412
# Parametros: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7826241134751774
# Parametros: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7827127659574468
# Parametros: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7867464539007092
# Parametros: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7846187943262412
# Parametros: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7826241134751774
# Parametros: {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7467641843971632
# Parametros: {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7572695035460993
# Parametros: {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7490248226950355
# Parametros: {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.744813829787234
# Parametros: {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.757313829787234
# Parametros: {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7656471631205675
# Parametros: {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7679078014184397
# Parametros: {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7783687943262412
# Parametros: {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7531028368794326
# Parametros: {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7678191489361702
# Parametros: {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7762854609929078
# Parametros: {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7867021276595745
# Parametros: {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7615691489361702
# Parametros: {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7635195035460993
# Parametros: {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7804521276595745
# Parametros: {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7825354609929078
# Parametros: {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7615691489361702
# Parametros: {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7635195035460993
# Parametros: {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7804521276595745
# Parametros: {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7825354609929078
# Parametros: {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7593528368794327
# Parametros: {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7867021276595745
# Parametros: {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7867907801418441
# Parametros: {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7909574468085107
# Parametros: {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7827127659574468
# Parametros: {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7910017730496455
# Parametros: {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7929964539007092
# Parametros: {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7867907801418441
# Parametros: {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7827127659574468
# Parametros: {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7910017730496455
# Parametros: {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7929964539007092
# Parametros: {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7867907801418441
# Parametros: {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7827127659574468
# Parametros: {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7910017730496455
# Parametros: {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7929964539007092
# Parametros: {'criterion': 'gini', 'max_depth': 15, 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7867907801418441
# Parametros: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.788741134751773
# Parametros: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7929078014184399
# Parametros: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.8012854609929076
# Parametros: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.8013741134751774
# Parametros: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7929521276595745
# Parametros: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7908687943262411
# Parametros: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7970744680851064
# Parametros: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7971631205673759
# Parametros: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7866578014184398
# Parametros: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7866578014184398
# Parametros: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7908244680851064
# Parametros: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7971631205673758
# Parametros: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7825354609929078
# Parametros: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7886968085106383
# Parametros: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7907801418439716
# Parametros: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.8034131205673759
# Parametros: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7825354609929078
# Parametros: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7886968085106383
# Parametros: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7907801418439716
# Parametros: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.8034131205673759
# Parametros: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7804964539007092
# Parametros: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7720301418439717
# Parametros: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.782491134751773
# Parametros: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7992907801418438
# Parametros: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.769991134751773
# Parametros: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7846187943262412
# Parametros: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.780363475177305
# Parametros: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7950797872340425
# Parametros: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.769991134751773
# Parametros: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7846187943262412
# Parametros: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.780363475177305
# Parametros: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7950797872340425
# Parametros: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.769991134751773
# Parametros: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7846187943262412
# Parametros: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.780363475177305
# Parametros: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7950797872340425
# Parametros: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7446808510638298
# Parametros: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7677304964539007
# Parametros: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7740248226950356
# Parametros: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7719414893617021
# Parametros: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.771941489361702
# Parametros: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7845744680851064
# Parametros: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7824024822695035
# Parametros: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7782801418439717
# Parametros: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7699024822695036
# Parametros: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7950354609929079
# Parametros: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7824024822695035
# Parametros: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7804078014184397
# Parametros: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7699911347517729
# Parametros: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7824468085106384
# Parametros: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.784618794326241
# Parametros: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7825354609929078
# Parametros: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7699911347517729
# Parametros: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7824468085106384
# Parametros: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.784618794326241
# Parametros: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7825354609929078
# Parametros: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7720301418439717
# Parametros: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7824911347517729
# Parametros: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7888297872340426
# Parametros: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7784131205673759
# Parametros: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7910017730496455
# Parametros: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7909574468085107
# Parametros: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.784663120567376
# Parametros: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7826241134751774
# Parametros: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7910017730496455
# Parametros: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7909574468085107
# Parametros: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.784663120567376
# Parametros: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7826241134751774
# Parametros: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7910017730496455
# Parametros: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7909574468085107
# Parametros: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.784663120567376
# Parametros: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7826241134751774
# Parametros: {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.759308510638298
# Parametros: {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7593085106382979
# Parametros: {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7594414893617021
# Parametros: {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7551861702127659
# Parametros: {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7677304964539007
# Parametros: {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7656471631205675
# Parametros: {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7678191489361701
# Parametros: {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7761968085106383
# Parametros: {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7571808510638298
# Parametros: {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7636081560283687
# Parametros: {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.774113475177305
# Parametros: {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.776241134751773
# Parametros: {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7636524822695036
# Parametros: {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7614804964539007
# Parametros: {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7826241134751774
# Parametros: {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7783687943262412
# Parametros: {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7636524822695036
# Parametros: {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7614804964539007
# Parametros: {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7826241134751774
# Parametros: {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7783687943262412
# Parametros: {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7678191489361701
# Parametros: {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7886968085106383
# Parametros: {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7950354609929079
# Parametros: {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7867464539007092
# Parametros: {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7930851063829787
# Parametros: {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7909574468085107
# Parametros: {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.790913120567376
# Parametros: {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7825797872340425
# Parametros: {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7930851063829787
# Parametros: {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7909574468085107
# Parametros: {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.790913120567376
# Parametros: {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7825797872340425
# Parametros: {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7930851063829787
# Parametros: {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7909574468085107
# Parametros: {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.790913120567376
# Parametros: {'criterion': 'entropy', 'max_depth': 15, 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7825797872340425
# ...
# Mean Score: 0.7446808510638298
# Parametros: {'criterion': 'log_loss', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7677304964539007
# Parametros: {'criterion': 'log_loss', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7740248226950356
# Parametros: {'criterion': 'log_loss', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7719414893617021
# Parametros: {'criterion': 'log_loss', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.771941489361702
# Parametros: {'criterion': 'log_loss', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7845744680851064
# Parametros: {'criterion': 'log_loss', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7824024822695035
# Parametros: {'criterion': 'log_loss', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7782801418439717
# Parametros: {'criterion': 'log_loss', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7699024822695036
# Parametros: {'criterion': 'log_loss', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7950354609929079
# Parametros: {'criterion': 'log_loss', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7824024822695035
# Parametros: {'criterion': 'log_loss', 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7804078014184397
# Parametros: {'criterion': 'log_loss', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7699911347517729
# Parametros: {'criterion': 'log_loss', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7824468085106384
# Parametros: {'criterion': 'log_loss', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.784618794326241
# Parametros: {'criterion': 'log_loss', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7825354609929078
# Parametros: {'criterion': 'log_loss', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7699911347517729
# Parametros: {'criterion': 'log_loss', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7824468085106384
# Parametros: {'criterion': 'log_loss', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.784618794326241
# Parametros: {'criterion': 'log_loss', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7825354609929078
# Parametros: {'criterion': 'log_loss', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7720301418439717
# Parametros: {'criterion': 'log_loss', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7824911347517729
# Parametros: {'criterion': 'log_loss', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7888297872340426
# Parametros: {'criterion': 'log_loss', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7784131205673759
# Parametros: {'criterion': 'log_loss', 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7910017730496455
# Parametros: {'criterion': 'log_loss', 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7909574468085107
# Parametros: {'criterion': 'log_loss', 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.784663120567376
# Parametros: {'criterion': 'log_loss', 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7826241134751774
# Parametros: {'criterion': 'log_loss', 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7910017730496455
# Parametros: {'criterion': 'log_loss', 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7909574468085107
# Parametros: {'criterion': 'log_loss', 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.784663120567376
# Parametros: {'criterion': 'log_loss', 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7826241134751774
# Parametros: {'criterion': 'log_loss', 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7910017730496455
# Parametros: {'criterion': 'log_loss', 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7909574468085107
# Parametros: {'criterion': 'log_loss', 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.784663120567376
# Parametros: {'criterion': 'log_loss', 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7826241134751774
# Parametros: {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.759308510638298
# Parametros: {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7593085106382979
# Parametros: {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7594414893617021
# Parametros: {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7551861702127659
# Parametros: {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7677304964539007
# Parametros: {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7656471631205675
# Parametros: {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7678191489361701
# Parametros: {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7761968085106383
# Parametros: {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7571808510638298
# Parametros: {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7636081560283687
# Parametros: {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.774113475177305
# Parametros: {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.776241134751773
# Parametros: {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7636524822695036
# Parametros: {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7614804964539007
# Parametros: {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7826241134751774
# Parametros: {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7783687943262412
# Parametros: {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7636524822695036
# Parametros: {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7614804964539007
# Parametros: {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7826241134751774
# Parametros: {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7783687943262412
# Parametros: {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7678191489361701
# Parametros: {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7886968085106383
# Parametros: {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.7950354609929079
# Parametros: {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7867464539007092
# Parametros: {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7930851063829787
# Parametros: {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7909574468085107
# Parametros: {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.790913120567376
# Parametros: {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7825797872340425
# Parametros: {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7930851063829787
# Parametros: {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7909574468085107
# Parametros: {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.790913120567376
# Parametros: {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7825797872340425
# Parametros: {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 5}
#
# ======================================================================
# Mean Score: 0.7930851063829787
# Parametros: {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 10}
#
# ======================================================================
# Mean Score: 0.7909574468085107
# Parametros: {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 25}
#
# ======================================================================
# Mean Score: 0.790913120567376
# Parametros: {'criterion': 'log_loss', 'max_depth': 15, 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 50}
#
# ======================================================================
# Mean Score: 0.7825797872340425

# %% [markdown]
# Imprimir los mejores resultados

# %%
print(f"Mejores hiperParametros encontrados: {grid_search.best_params_}")
print("-"*50)
print(f"Mejor puntuacion de valudacion cruzada: {grid_search.best_score_}\n")
# Out:
# Mejores hiperParametros encontrados: {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 50}
# --------------------------------------------------
# Mejor puntuacion de valudacion cruzada: 0.8034131205673759

# %% [markdown]
# Modelo decision tree con parametros optimizados

# %%
best_clf = grid_search.best_estimator_

print(best_clf)
# Out:
# RandomForestClassifier(max_depth=5, min_samples_split=6, n_estimators=50,
#                        random_state=42)

# %% [markdown]
# # Evaluacion del modelo

# %% [markdown]
# Calculo de las prediciones en Train y TesT

# %%
y_train_pred = best_clf.predict(X_train)

y_test_pred = best_clf.predict(X_test)

# %% [markdown]
# Graficamos la matriz de  confusion

# %%
cm = confusion_matrix(y_test, y_test_pred, labels=best_clf.classes_)

sns.heatmap(cm, annot=True, fmt="d", cmap='gray', square=True, cbar=False)
plt.ylabel("True Label")
plt.xlabel("Predicted Label")
plt.show()

# %% [markdown]
# ## Calculo de las metricas
#
# - Calculando el accuracy en Train
#
# - Calculando el accuracy en Test

# %%
# Train
train_accuracy = accuracy_score(y_train, y_train_pred)

# Test
test_accuracy = accuracy_score(y_test, y_test_pred)

print("Train accuracy: ", train_accuracy)
print("-"*60)
print("Test accuracy: ", test_accuracy)
# Out:
# Train accuracy:  0.8347280334728033
# ------------------------------------------------------------
# Test accuracy:  0.8300970873786407

# %% [markdown]
# Verificamos el feature importaces

# %%
# Vamos a ordenar las importancias
importances = best_clf.feature_importances_


# Todas las variables que no son el target
columns = X.columns

# Creacion de un DataFrame con las variables y sus importancias
# Ordenar el DataFrame por importancia en orden descendente

df_scores = pd.DataFrame(pd.Series(importances, index=columns).sort_values(ascending=False)).T


# anotaciones
for index, value in enumerate(df_scores.values.flatten()):
    plt.annotate(f'{value:.2f}', xy=(index, value), ha='center', va='bottom')

# # Gracion del barplot
sns.barplot(data=df_scores, saturation=2.0, edgecolor="black", linewidth=2)
plt.title("Importancia de cada Feature")
plt.show()

# %% [markdown]
# - Podemos observar que para la clasificación del modelo en base a la variable target: `Survived`, los **features más importantes** son: *Sex, seguido de Age y luego de Pclass*.
#
# - **SibSp** y **ParCh no tienen un impacto significativo** en la capacidad del modelo para predecir la variable objetivo, *se podrían eliminar sin afectar la capacidad de predicción.*
#
# - Es importante destacar que se observa una performance parecida en la métrica de **Accuracy** para los datos de **Train** y de **Test**, lo cual es claramente positivo para nuestro modelo.
